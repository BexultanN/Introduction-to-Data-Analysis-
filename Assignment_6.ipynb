# %% [markdown]
# ## Assignment 6
# Data cleaning

# %%
# read and clean the airbnb.csv dataset

# find na values --> replace them 
# find outliers
# do label encoding

# data visualization is bonus 25%

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/'CSS 328 - Intro to Data analysis course'/'WEEK 10'/
# Out:
# /content/drive/MyDrive/CSS 328 - Intro to Data analysis course/WEEK 10

# %%
import pandas as pd
airbnb = pd.read_csv('airbnb.csv')
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10019 entries, 0 to 10018
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          10019 non-null  int64
#  1   listing_id          10019 non-null  int64
#  2   name                10014 non-null  object
#  3   host_id             10019 non-null  int64
#  4   host_name           10017 non-null  object
#  5   neighbourhood_full  10019 non-null  object
#  6   coordinates         10019 non-null  object
#  7   room_type           10019 non-null  object
#  8   price               9781 non-null   object
#  9   number_of_reviews   10019 non-null  int64
#  10  last_review         7944 non-null   object
#  11  reviews_per_month   7944 non-null   float64
#  12  availability_365    10019 non-null  int64
#  13  rating              7944 non-null   float64
#  14  number_of_stays     7944 non-null   float64
# ...

# %%
airbnb.head(10)
# Out:
#    unnamed:_0  listing_id                                               name  \
# 0           0    13740704  Cozy,budget friendly, cable inc, private entra...
# 1           1    22005115              Two floor apartment near Central Park
# 2           2    21667615                  Beautiful 1BR in Brooklyn Heights
# 3           3     6425850                          Spacious, charming studio
# 4           4    22986519              Bedroom on the lively Lower East Side
# 5           5      271954                     Beautiful brownstone apartment
# 6           6    33473567             Hamilton Heights Full Floor Garden Apt
# 7           7    14218742  Luxury/3bedroom/3bthrm/Privateprkng/beach/rstrnts
# 8           8    15125599  Beautiful One Bedroom Apartment Near Central Park
# 9           9    24553891    Enjoy all of Manhattan. Big Apple! A Mini-MOMA!
#
#      host_id  host_name            neighbourhood_full  \
# 0   20583125     Michel           Brooklyn, Flatlands
# ...

# %%
airbnb.dtypes
# Out:
# unnamed:_0              int64
# listing_id              int64
# name                   object
# host_id                 int64
# host_name              object
# neighbourhood_full     object
# coordinates            object
# room_type              object
# price                 float64
# number_of_reviews       int64
# last_review            object
# reviews_per_month     float64
# availability_365        int64
# rating                float64
# number_of_stays       float64
# 5_stars               float64
# listing_added          object
# dtype: object

# %%
airbnb.isna()
# Out:
#        Unnamed: 0  listing_id   name  host_id  host_name  neighbourhood_full  \
# 0           False       False  False    False      False               False
# 1           False       False  False    False      False               False
# 2           False       False  False    False      False               False
# 3           False       False  False    False      False               False
# 4           False       False  False    False      False               False
# ...           ...         ...    ...      ...        ...                 ...
# 10014       False       False  False    False      False               False
# 10015       False       False  False    False      False               False
# 10016       False       False  False    False      False               False
# 10017       False       False  False    False      False               False
# 10018       False       False  False    False      False               False
#
# ...

# %%
airbnb = pd.read_csv('airbnb.csv')
print airbnb['listing_id'].isnull()
# Out:
#   Cell In [93], line 2
#     print airbnb['listing_id'].isnull()
#           ^
# SyntaxError: invalid syntax

# %%
airbnb.isnull().sum()
# Out:
# Unnamed: 0               0
# listing_id               0
# name                     5
# host_id                  0
# host_name                2
# neighbourhood_full       0
# coordinates              0
# room_type                0
# price                  238
# number_of_reviews        0
# last_review           2075
# reviews_per_month     2075
# availability_365         0
# rating                2075
# number_of_stays       2075
# 5_stars               2075
# listing_added            0
# dtype: int64

# %%
airbnb.fillna(0, inplace = True)
missing_vals = ["NA", "NaN", "", None, np.NaN]
missing = airbnb.isin(missing_vals)
airbnb.mask(missing, "missing").head()
airbnb.isnull().sum()
# Out:
# Unnamed: 0            0
# listing_id            0
# name                  0
# host_id               0
# host_name             0
# neighbourhood_full    0
# coordinates           0
# room_type             0
# price                 0
# number_of_reviews     0
# last_review           0
# reviews_per_month     0
# availability_365      0
# rating                0
# number_of_stays       0
# 5_stars               0
# listing_added         0
# dtype: int64

# %%
airbnb.describe()
# Out:
#          Unnamed: 0    listing_id       host_id  number_of_reviews  \
# count  10019.000000  1.001900e+04  1.001900e+04       10019.000000
# mean    5009.000000  1.927634e+07  6.795923e+07          22.459727
# std     2892.380507  1.095056e+07  7.863106e+07          43.173896
# min        0.000000  3.831000e+03  2.787000e+03           0.000000
# 25%     2504.500000  9.674772e+06  7.910880e+06           1.000000
# 50%     5009.000000  2.007030e+07  3.165167e+07           5.000000
# 75%     7513.500000  2.933864e+07  1.074344e+08          22.000000
# max    10018.000000  3.648724e+07  2.741034e+08         510.000000
#
#        reviews_per_month  availability_365        rating  number_of_stays  \
# count       10019.000000      10019.000000  10019.000000     10019.000000
# mean            1.073493        112.284260      3.183038        26.951672
# std             1.539481        131.636043      1.705552        51.808675
# ...

# %%
airbnb.drop(airbnb.columns[airbnb.isnull().mean()>0.50], axis=1)
# Out:
#        unnamed:_0  listing_id  \
# 0               0    13740704
# 1               1    22005115
# 2               2    21667615
# 3               3     6425850
# 4               4    22986519
# ...           ...         ...
# 10014       10014    22307861
# 10015       10015      953275
# 10016       10016     3452835
# 10017       10017    23540194
# 10018       10018    32876011
#
#                                                     name    host_id host_name  \
# 0      Cozy,budget friendly, cable inc, private entra...   20583125    Michel
# 1                  Two floor apartment near Central Park   82746113   Cecilia
# 2                      Beautiful 1BR in Brooklyn Heights      78251    Leslie
# 3                              Spacious, charming studio   32715865    Yelena
# 4                  Bedroom on the lively Lower East Side  154262349    Brooke
# ...                                                  ...        ...       ...
# ...

# %%
airbnb[airbnb['rating'] > 5.0]
airbnb.drop(airbnb[airbnb['rating'] > 5.0].index, inplace = True, axis = 0)
sns.distplot(airbnb['rating'], bins = 20)
plt.show()
# Out:
# C:\Users\Beksultan\AppData\Local\Temp\ipykernel_9336\299421423.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airbnb['rating'], bins = 20)

# %%
import pandas as pd
import numpy as np
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns

sns.distplot(airbnb['listing_id'])
# Out:
# C:\Users\Beksultan\AppData\Local\Temp\ipykernel_4628\2913672049.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airbnb['listing_id'])
# <AxesSubplot: xlabel='listing_id', ylabel='Density'>

# %%
sns.boxplot(airbnb['listing_id'])
# Out:
# <AxesSubplot: >

# %%
import pandas as pd
airbnb = pd.read_csv('airbnb.csv')
airbnb.isnull().sum()

# %%
airbnb.drop(airbnb.columns[airbnb.isnull().mean()>0.50], axis=1)
# Out:
#        unnamed:_0  listing_id  \
# 0               0    13740704
# 1               1    22005115
# 2               2    21667615
# 3               3     6425850
# 4               4    22986519
# ...           ...         ...
# 10014       10014    22307861
# 10015       10015      953275
# 10016       10016     3452835
# 10017       10017    23540194
# 10018       10018    32876011
#
#                                                     name    host_id host_name  \
# 0      Cozy,budget friendly, cable inc, private entra...   20583125    Michel
# 1                  Two floor apartment near Central Park   82746113   Cecilia
# 2                      Beautiful 1BR in Brooklyn Heights      78251    Leslie
# 3                              Spacious, charming studio   32715865    Yelena
# 4                  Bedroom on the lively Lower East Side  154262349    Brooke
# ...                                                  ...        ...       ...
# ...

# %%
import missingno as msno 
msno.bar(airbnb)
# Out:
# <AxesSubplot: >

# %%
a = airbnb['reviews_per_month'].mean()
a
# Out:
# 1.073493362611039

# %%
airbnb.isna().sum()
# Out:
# Unnamed: 0            0
# listing_id            0
# name                  0
# host_id               0
# host_name             0
# neighbourhood_full    0
# coordinates           0
# room_type             0
# price                 0
# number_of_reviews     0
# last_review           0
# reviews_per_month     0
# availability_365      0
# rating                0
# number_of_stays       0
# 5_stars               0
# listing_added         0
# dtype: int64

# %%
print("Number of records: {}".format(airbnb.shape[0]))
print("Number of columns: {}".format(airbnb.shape[1]))
# Out:
# Number of records: 10019
# Number of columns: 17

# %%
airbnb.reset_index(inplace=True, drop=True)
print(airbnb.columns.to_list())
# Out:
# ['Unnamed: 0', 'listing_id', 'name', 'host_id', 'host_name', 'neighbourhood_full', 'coordinates', 'room_type', 'price', 'number_of_reviews', 'last_review', 'reviews_per_month', 'availability_365', 'rating', 'number_of_stays', '5_stars', 'listing_added']

# %%
airbnb.columns = [col.lower().replace(" ","_") for col in airbnb.columns]
print(airbnb.columns.to_list())
# Out:
# ['unnamed:_0', 'listing_id', 'name', 'host_id', 'host_name', 'neighbourhood_full', 'coordinates', 'room_type', 'price', 'number_of_reviews', 'last_review', 'reviews_per_month', 'availability_365', 'rating', 'number_of_stays', '5_stars', 'listing_added']

# %%
missing_val_summary = airbnb.isnull().sum()
missing_val_summary = missing_val_summary[missing_val_summary > 0].sort_values(ascending=False)
missing_val_summary*100/len(airbnb)
# Out:
# Series([], dtype: float64)

# %%
airbnb.nunique().sort_values(ascending=False)
# Out:
# unnamed:_0            10019
# listing_id             9999
# coordinates            9997
# name                   9920
# host_id                8921
# rating                 7930
# 5_stars                7929
# host_name              4085
# listing_added          1235
# last_review            1223
# reviews_per_month       684
# price                   434
# availability_365        366
# number_of_reviews       271
# number_of_stays         271
# neighbourhood_full      198
# room_type                 7
# dtype: int64

# %%
airbnb['room_type'] = airbnb['room_type'].str.lower()
airbnb['room_type'].unique()
# Out:
# array(['private room', 'entire home/apt', 'private', 'shared room',
#        'home', '   shared room      '], dtype=object)

# %%
airbnb['room_type'] = airbnb['room_type'].str.strip()
airbnb['room_type'].unique()
# Out:
# array(['private room', 'entire home/apt', 'private', 'shared room',
#        'home'], dtype=object)

# %%
mappings = {'private room':'Private Room',
            'private':'Private Room',
            'entire home/apt':'Entire Place',
            'shared room':'Shared Room',
            'home':'Entire Place'}
airbnb['room_type'] = airbnb['room_type'].replace(mappings)
airbnb['room_type'].unique()
# Out:
# array(['Private Room', 'Entire Place', 'Shared Room'], dtype=object)

# %%
airbnb['neighbourhood_full'].head()
borough_neighbourhood = airbnb['neighbourhood_full'].str.split(',', expand = True)
borough_neighbourhood.head()
# Out:
#            0                  1
# 0   Brooklyn          Flatlands
# 1  Manhattan    Upper West Side
# 2   Brooklyn   Brooklyn Heights
# 3  Manhattan    Upper West Side
# 4  Manhattan    Lower East Side

# %%
airbnb['borough'] = borough_neighbourhood[0]
airbnb['neighbourhood'] = borough_neighbourhood[1]
airbnb[['borough', 'neighbourhood']].head()
# Out:
#      borough      neighbourhood
# 0   Brooklyn          Flatlands
# 1  Manhattan    Upper West Side
# 2   Brooklyn   Brooklyn Heights
# 3  Manhattan    Upper West Side
# 4  Manhattan    Lower East Side

# %%
airbnb.drop('neighbourhood_full', axis=1, inplace = True)
print(airbnb['borough'].unique())
print(airbnb['neighbourhood'].unique())
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Bronx' 'Staten Island']
# [' Flatlands' ' Upper West Side' ' Brooklyn Heights' ' Lower East Side'
#  ' Greenwich Village' ' Harlem' ' Sheepshead Bay' ' Theater District'
#  ' Bushwick' ' Laurelton' ' Mott Haven' ' Flushing' ' Crown Heights'
#  ' Midtown' ' Financial District' ' East Village' ' Park Slope'
#  ' Washington Heights' ' Williamsburg' ' Chelsea' ' Bedford-Stuyvesant'
#  ' Gowanus' ' Upper East Side' ' Ditmars Steinway' ' Cypress Hills'
#  " Hell's Kitchen" ' Ridgewood' ' Marble Hill' ' Kips Bay'
#  ' Prospect Heights' ' East New York' ' Concord' ' Stapleton' ' Astoria'
#  ' East Harlem' ' Sunnyside' ' Gramercy' ' Prospect-Lefferts Gardens'
#  ' Sunset Park' ' Forest Hills' ' Windsor Terrace' ' Clinton Hill'
#  ' Murray Hill' ' Flatiron District' ' Greenpoint' ' East Flatbush'
#  ' Tribeca' ' Woodhaven' ' Fort Greene' ' Inwood' ' Chinatown'
#  ' Rockaway Beach' ' Woodside' ' Bayside' ' Bensonhurst' ' SoHo'
# ...

# %%
airbnb['neighbourhood'] = airbnb['neighbourhood'].str.strip()
airbnb['neighbourhood'].unique()
sns.distplot(airbnb['rating'], bins = 20)
plt.show()
# Out:
# C:\Users\Beksultan\AppData\Local\Temp\ipykernel_9336\3838536057.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airbnb['rating'], bins = 20)

# %%
airbnb['room_type'].value_counts()/len(airbnb)
# Out:
# Entire home/apt         0.511029
# Private room            0.447849
# Shared room             0.015471
# Private                 0.008883
#    Shared room          0.007087
# home                    0.006587
# PRIVATE ROOM            0.003094
# Name: room_type, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime as dt
import missingno as msno
import datetime as dt

sns.distplot(airbnb['rating'], bins = 10)
plt.title("Distribution of Listing Ratings")
plt.show()
# Out:
# C:\Users\Beksultan\AppData\Local\Temp\ipykernel_9336\2520767935.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airbnb['rating'], bins = 10)

# %%
airbnb['rating'].max()
# Out:
# 4.999561104773598

# %%
airbnb['room_type'].unique()
airbnb['room_type'].value_counts()
# Out:
# Entire home/apt         5120
# Private room            4487
# Shared room              155
# Private                   89
#    Shared room            71
# home                      66
# PRIVATE ROOM              31
# Name: room_type, dtype: int64

# %%
airbnb['coordinates'] = airbnb['coordinates'].str.replace("(","")
airbnb['coordinates'] = airbnb['coordinates'].str.replace(")","")
airbnb['coordinates'].head()
# Out:
# C:\Users\Beksultan\AppData\Local\Temp\ipykernel_9336\719988359.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   airbnb['coordinates'] = airbnb['coordinates'].str.replace("(","")
# C:\Users\Beksultan\AppData\Local\Temp\ipykernel_9336\719988359.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   airbnb['coordinates'] = airbnb['coordinates'].str.replace(")","")
# 0    40.63222, -73.93398
# 1    40.78761, -73.96862
# 2     40.7007, -73.99517
# 3    40.79169, -73.97498
# 4    40.71884, -73.98354
# Name: coordinates, dtype: object

# %%
lat_long = airbnb["coordinates"].str.split(",", expand = True)
lat_long.head()
# Out:
#           0           1
# 0  40.63222   -73.93398
# 1  40.78761   -73.96862
# 2   40.7007   -73.99517
# 3  40.79169   -73.97498
# 4  40.71884   -73.98354

# %%
airbnb['latitude'] = lat_long[0]
airbnb['longitude'] = lat_long[1]
airbnb.head()
# Out:
#    unnamed:_0  listing_id                                               name  \
# 0           0    13740704  Cozy,budget friendly, cable inc, private entra...
# 1           1    22005115              Two floor apartment near Central Park
# 2           2    21667615                  Beautiful 1BR in Brooklyn Heights
# 3           3     6425850                          Spacious, charming studio
# 4           4    22986519              Bedroom on the lively Lower East Side
#
#      host_id host_name          neighbourhood_full          coordinates  \
# 0   20583125    Michel         Brooklyn, Flatlands  40.63222, -73.93398
# 1   82746113   Cecilia  Manhattan, Upper West Side  40.78761, -73.96862
# 2      78251    Leslie  Brooklyn, Brooklyn Heights   40.7007, -73.99517
# 3   32715865    Yelena  Manhattan, Upper West Side  40.79169, -73.97498
# 4  154262349    Brooke  Manhattan, Lower East Side  40.71884, -73.98354
#
# ...

# %%
airbnb['latitude'] = airbnb['latitude'].astype('float')
airbnb['longitude'] = airbnb['longitude'].astype('float')
airbnb.dtypes
# Out:
# unnamed:_0              int64
# listing_id              int64
# name                   object
# host_id                 int64
# host_name              object
# neighbourhood_full     object
# coordinates            object
# room_type              object
# price                 float64
# number_of_reviews       int64
# last_review            object
# reviews_per_month     float64
# availability_365        int64
# rating                float64
# number_of_stays       float64
# 5_stars               float64
# listing_added          object
# latitude              float64
# longitude             float64
# dtype: object

# %%
airbnb.drop('coordinates',axis=1, inplace = True)

# %%
airbnb['price'] = airbnb['price'].astype('float')
airbnb['price'].mean()
sns.distplot(airbnb['price'], bins = 20)
plt.show()
# Out:
# C:\Users\Beksultan\AppData\Local\Temp\ipykernel_9336\1923772230.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(airbnb['price'], bins = 20)

# %%
airbnb['listing_added'] = pd.to_datetime(airbnb['listing_added'], format = '%Y-%m-%d')
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'], format = '%Y-%m-%d')
airbnb[['listing_added','last_review']].head()
# Out:
#   listing_added last_review
# 0    2018-06-08  2018-12-12
# 1    2018-12-25  2019-06-30
# 2    2018-08-15  1970-01-01
# 3    2017-03-20  2017-09-23
# 4    2020-10-23  2019-06-12

# %%
df = airbnb.duplicated(subset = 'listing_id', keep = False)
print(df)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10014    False
# 10015    False
# 10016    False
# 10017    False
# 10018    False
# Length: 10016, dtype: bool

# %%
airbnb = airbnb.drop_duplicates()
df = airbnb.duplicated(subset = 'listing_id', keep = False)
airbnb[df].sort_values('listing_id')
# Out:
#       unnamed:_0  listing_id  \
# 1145        1145      253806
# 6562        6562      253806
# 8699        8699     2044392
# 5761        5761     2044392
# 4187        4187     4244242
# 2871        2871     4244242
# 77            77     7319856
# 2255        2255     7319856
# 555          555     9078222
# 7933        7933     9078222
# 1481        1481    15027024
# 3430        3430    15027024
# 3065        3065    16518377
# 5397        5397    16518377
# 3007        3007    17861841
# 368          368    17861841
# 6438        6438    19477677
# 5251        5251    19477677
# 5454        5454    21106251
# 6832        6832    21106251
# 5246        5246    22014840
# 6068        6068    22014840
# 5861        5861    23990868
# 6132        6132    23990868
# 7769        7769    26554879
# 7116        7116    26554879
# 5236        5236    29844951
# 9425        9425    29844951
# 7316        7316    31470004
# 9322        9322    31470004
# 1338        1338    32610834
# ...

# %%
airbnb.to_csv('assignment6.csv', index=False)
